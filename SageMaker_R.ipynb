# %%
(t=seq(0,10,0.1))

# %%
library(ggplot2)

ggplot(data.frame(x=t), aes(x)) + 
    stat_function(fun=sin)
    #stat_function(fun=log)
# Out:
# plot without title

# %%
#we can define a function in R.

sigmoid <- function(x) {
   1 / (1 + exp(-x))
}

# %%
ggplot()+
stat_function(aes(seq(-5, 5, 0.01), lwd=2), fun = function(x) {
   1 / (1 + exp(-x))
}
             ) + 
    xlab("x")
# Out:
# plot without title
